# %% [markdown]
# <h1>YOLO (You Only look One) this is fast object detection model,which is used to build high accuracy of Data</h1>

# %% [markdown]
# Module Used in below Code
# ultralytics:It contain the pretrined model in the library
# What you can do with Ultralytics
# Using Ultralytics YOLO, tum:
#  1. Object Detection:Person, car, mobile detect karna
#  2. Pose Detection:Body keypoints (like MediaPipe alternative)
#  3. Image Classification:Image kis category ka hai
#  4. Segmentation:Object ka exact shape detect karnal-cv2

# %%
# pip install ultralytics

# %%
# Load YOLOv8 model (auto-downloads)
# model = YOLO("yolov8n.pt")  nano model (fast)
# YOLO("yolov8n.pt")  # Fastest ⚡
# YOLO("yolov8s.pt")  # Balanced
# YOLO("yolov8m.pt")  # Better accuracy
# YOLO("yolov8l.pt")  # High accuracy

# %%
from ultralytics import YOLO
import cv2

model = YOLO("yolov8n.pt")  # pretrained model

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    
    results = model(frame)

    annotated_frame = results[0].plot()

    cv2.imshow("YOLO Detection", annotated_frame)

    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 2 persons, 192.9ms
# Speed: 46.7ms preprocess, 192.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 143.7ms
# Speed: 4.3ms preprocess, 143.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 134.9ms
# Speed: 3.7ms preprocess, 134.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 139.4ms
# Speed: 6.1ms preprocess, 139.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 143.5ms
# Speed: 2.9ms preprocess, 143.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 151.1ms
# Speed: 5.3ms preprocess, 151.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 139.4ms
# Speed: 4.4ms preprocess, 139.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 127.6ms
# ...
